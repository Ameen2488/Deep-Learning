# %% [markdown]
# <a href="https://colab.research.google.com/github/Ameen2488/Deep-Learning/blob/main/DMP__Task_BPE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
import random
from sklearn.metrics import r2_score

# %%
df_bromley = pd.read_excel('/content/Bromley_data.xlsx')
df_bromley
# Out:
#     Salinity  BPT     TE
# 0    0.61860   60  0.071
# 1    0.63690   60  0.072
# 2    1.12630   60  0.128
# 3    1.17350   60  0.134
# 4    1.57070   60  0.178
# 5    1.68670   60  0.192
# 6    2.22542   60  0.258
# 7    3.05420   60  0.356
# 8    3.73500   60  0.440
# 9    4.52850   60  0.542
# 10   5.17800   60  0.629
# 11   5.76350   60  0.709
# 12   6.42120   60  0.803
# 13   7.13540   60  0.907
# 14   0.62390   80  0.081
# 15   1.25300   80  0.163
# 16   1.85040   80  0.241
# 17   2.53750   80  0.332
# 18   2.64300   80  0.347
# 19   3.46700   80  0.461
# 20   3.46900   80  0.461
# 21   4.02540   80  0.542
# 22   4.77900   80  0.654
# 23   5.39290   80  0.749
# 24   5.83520   80  0.816
# 25   5.91260   80  0.830
# 26   6.32310   80  0.894
# 27   6.40640   80  0.910
# 28   0.79810  100  0.118
# 29   1.00100  100  0.147
# 30   1.25660  100  0.185
# 31   1.68300  100  0.248
# 32   1.71170  100  0.251
# 33   2.15100  100  0.318
# 34   3.03000  100  0.454
# 35   3.35410  100  0.505
# 36   3.47300  100  0.524
# 37   3.61800  100  0.547
# 38   4.28100  100  0.657
# 39   4.87600  100  0.756
# 40   5.05550  100  0.789
# 41   5.06480  100  0.790
# 42   0.19101  120  0.033
# 43   0.68870  120  0.116
# 44   1.28130  120  0.213
# 45   1.94570  120  0.324
# 46   2.53370  120  0.425
# 47   2.60120  120  0.437
# 48   3.05820  120  0.516
# 49   3.35340  120  0.567
# 50   3.90860  120  0.670
# 51   4.42080  120  0.764
# 52   4.91100  120  0.856
# 53   5.40380  120  0.951
# 54   5.92910  120  1.056
# 55   6.41080  120  1.154

# %%
# @title Salinity vs TE Concentration by BPT Level

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Salinity', y='TE', hue='BPT', data=df_bromley)
plt.xlabel('Salinity')
plt.ylabel('Trace Element (TE) Concentration')
_ = plt.title('Salinity vs TE Concentration by BPT Level')

# %%
# @title Salinity vs TE Concentration

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(df_bromley['Salinity'], df_bromley['TE'])
plt.xlabel('Salinity')
plt.ylabel('Trace Element (TE) Concentration')
_ = plt.title('Salinity vs TE Concentration')

# %%
# @title BPT

from matplotlib import pyplot as plt
df_bromley['BPT'].plot(kind='line', figsize=(8, 4), title='BPT')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df_bromley.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Salinity  56 non-null     float64
#  1   BPT       56 non-null     int64
#  2   TE        56 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.4 KB

# %%
df_badger = pd.read_excel('/content/Badger_data.xlsx')
df_badger
# Out:
#     Salinity    BPT    TE
# 0       0.88   37.8  0.07
# 1       1.76   37.8  0.14
# 2       2.64   37.8  0.17
# 3       3.53   37.8  0.28
# 4       4.41   37.8  0.38
# ..       ...    ...   ...
# 63     11.46  121.1  2.36
# 64     12.37  121.1  2.64
# 65     13.21  121.1  2.81
# 66     14.10  121.1  2.99
# 67     14.98  121.1  3.33
#
# [68 rows x 3 columns]

# %%
# prompt: Using dataframe df_badger: scatter with BPT and TE and Salinity as a legend

import altair as alt
alt.Chart(df_badger).mark_point().encode(
    x='BPT',
    y='TE',
    color='Salinity'
)
# Out:
# alt.Chart(...)

# %%
# @title Salinity

from matplotlib import pyplot as plt
df_badger['Salinity'].plot(kind='hist', bins=20, title='Salinity')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_fabuss = pd.read_excel('/content/Fabuss_data.xlsx')
df_fabuss
# Out:
#      Salinity  BPT      TE
# 0         1.5    20  0.118
# 1         1.5    30  0.131
# 2         1.5    40  0.144
# 3         1.5    50  0.157
# 4         1.5    60  0.170
# ..        ...   ...    ...
# 331      13.0   110  2.627
# 332      13.0   120  2.765
# 333      13.0   130  2.902
# 334      13.0   140  3.041
# 335      13.0   150  3.179
#
# [336 rows x 3 columns]

# %%
# prompt: Using dataframe df_fabuss: scatter with BPT and TE and Salinity as a discreet legend point

import altair as alt
alt.Chart(df_fabuss).mark_point().encode(
    x='BPT ',
    y='TE',
    color='Salinity:N'  # Specify Salinity as a nominal (discrete) variable for the legend
)
# Out:
# alt.Chart(...)

# %%
# @title BPT  vs TE

from matplotlib import pyplot as plt
df_fabuss.plot(kind='scatter', x='BPT ', y='TE', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df_fabuss.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Salinity  336 non-null    float64
#  1   BPT       336 non-null    int64
#  2   TE        336 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 8.0 KB

# %%
# Convert Pandas to Numpy

df_fabuss_np = df_fabuss.to_numpy()
df_fabuss_np
# Out:
# array([[1.500e+00, 2.000e+01, 1.180e-01],
#        [1.500e+00, 3.000e+01, 1.310e-01],
#        [1.500e+00, 4.000e+01, 1.440e-01],
#        ...,
#        [1.300e+01, 1.300e+02, 2.902e+00],
#        [1.300e+01, 1.400e+02, 3.041e+00],
#        [1.300e+01, 1.500e+02, 3.179e+00]])

# %%
df_fabuss_np.shape
# Out:
# (336, 3)

# %%
X = df_fabuss_np[:, 0:-1]
X

y = df_fabuss_np[:, 2:3]
y
# Out:
# array([[0.118 ],
#        [0.131 ],
#        [0.144 ],
#        [0.157 ],
#        [0.17  ],
#        [0.183 ],
#        [0.196 ],
#        [0.209 ],
#        [0.222 ],
#        [0.235 ],
#        [0.248 ],
#        [0.261 ],
#        [0.274 ],
#        [0.287 ],
#        [0.16  ],
#        [0.177 ],
#        [0.195 ],
#        [0.212 ],
#        [0.229 ],
#        [0.247 ],
#        [0.264 ],
#        [0.282 ],
#        [0.299 ],
#        [0.317 ],
#        [0.334 ],
#        [0.352 ],
#        [0.37  ],
#        [0.387 ],
#        [0.203 ],
#        [0.225 ],
#        [0.247 ],
#        [0.269 ],
#        [0.291 ],
#        [0.313 ],
#        [0.335 ],
#        [0.357 ],
#        [0.379 ],
#        [0.401 ],
#        [0.423 ],
#        [0.445 ],
#        [0.468 ],
#        [0.49  ],
#        [0.247 ],
#        [0.274 ],
#        [0.3   ],
#        [0.327 ],
#        [0.354 ],
#        [0.38  ],
#        [0.407 ],
#        [0.434 ],
#        [0.46  ],
#        [0.487 ],
#        [0.514 ],
#        [0.541 ],
#        [0.568 ],
#        [0.595 ],
#        [0.293 ],
#        [0.324 ],
#        [0.355 ],
#        [0.387 ],
#        [0.418 ],
#        [0.449 ],
#        [0.481 ],
#        [0.512 ],
#        [0.544 ],
#        [0.575 ],
#        [0.607 ],
#        [0.639 ],
#        [0.67  ],
#        [0.702 ],
#        [0.34  ],
#        [0.376 ],
#        [0.412 ],
#        [0.448 ],
#        [0.484 ],
#        [0.52  ],
#        [0.556 ],
#        [0.593 ],
#        [0.629 ],
#        [0.666 ],
#        [0.702 ],
#        [0.738 ],
#        [0.775 ],
#        [0.812 ],
#        [0.388 ],
#        [0.429 ],
#        [0.47  ],
#        [0.511 ],
#        [0.552 ],
#        [0.593 ],
#        [0.634 ],
#        [0.675 ],
#        [0.716 ],
#        [0.758 ],
#        [0.79  ],
#        [0.84  ],
#        [0.882 ],
#        [0.923 ],
#        [0.437 ],
#        [0.483 ],
#        [0.529 ],
#        [0.575 ],
#        [0.621 ],
#        [0.667 ],
#        [0.713 ],
#        [0.759 ],
#        [0.805 ],
#        [0.852 ],
#        [0.898 ],
#        [0.945 ],
#        [0.991 ],
#        [1.038 ],
#        [0.488 ],
#        [0.538 ],
#        [0.589 ],
#        [0.64  ],
#        [0.691 ],
#        [0.743 ],
#        [0.794 ],
#        [0.845 ],
#        [0.896 ],
#        [0.948 ],
#        [0.999 ],
#        [1.051 ],
#        [1.102 ],
#        [1.154 ],
#        [0.539 ],
#        [0.595 ],
#        [0.651 ],
#        [0.708 ],
#        [0.764 ],
#        [0.82  ],
#        [0.876 ],
#        [0.933 ],
#        [0.989 ],
#        [1.046 ],
#        [1.103 ],
#        [1.059 ],
#        [1.216 ],
#        [1.273 ],
#        [0.592 ],
#        [0.654 ],
#        [0.715 ],
#        [0.776 ],
#        [0.838 ],
#        [0.899 ],
#        [0.961 ],
#        [1.022 ],
#        [1.084 ],
#        [1.146 ],
#        [1.208 ],
#        [1.27  ],
#        [1.332 ],
#        [1.394 ],
#        [0.647 ],
#        [0.713 ],
#        [0.78  ],
#        [0.846 ],
#        [0.913 ],
#        [7.    ],
#        [1.047 ],
#        [1.114 ],
#        [1.181 ],
#        [1.248 ],
#        [1.315 ],
#        [1.382 ],
#        [1.45  ],
#        [1.1517],
#        [0.702 ],
#        [0.774 ],
#        [0.846 ],
#        [0.918 ],
#        [0.99  ],
#        [1.062 ],
#        [1.135 ],
#        [1.207 ],
#        [1.279 ],
#        [1.352 ],
#        [1.425 ],
#        [1.497 ],
#        [1.57  ],
#        [1.643 ],
#        [0.759 ],
#        [0.836 ],
#        [0.914 ],
#        [0.991 ],
#        [1.069 ],
#        [1.146 ],
#        [1.224 ],
#        [1.302 ],
#        [1.38  ],
#        [1.458 ],
#        [1.536 ],
#        [1.614 ],
#        [1.693 ],
#        [1.771 ],
#        [0.817 ],
#        [0.9   ],
#        [0.983 ],
#        [1.066 ],
#        [1.149 ],
#        [1.232 ],
#        [1.315 ],
#        [1.399 ],
#        [1.482 ],
#        [1.566 ],
#        [1.65  ],
#        [1.734 ],
#        [1.817 ],
#        [1.902 ],
#        [0.876 ],
#        [0.965 ],
#        [1.053 ],
#        [1.142 ],
#        [1.231 ],
#        [1.319 ],
#        [1.408 ],
#        [1.497 ],
#        [1.587 ],
#        [1.676 ],
#        [1.765 ],
#        [1.855 ],
#        [1.944 ],
#        [2.034 ],
#        [0.937 ],
#        [1.031 ],
#        [1.125 ],
#        [1.219 ],
#        [1.314 ],
#        [1.408 ],
#        [1.503 ],
#        [1.598 ],
#        [1.693 ],
#        [1.788 ],
#        [1.883 ],
#        [1.978 ],
#        [2.074 ],
#        [2.169 ],
#        [0.999 ],
#        [1.098 ],
#        [1.198 ],
#        [1.298 ],
#        [1.399 ],
#        [1.499 ],
#        [1.599 ],
#        [1.7   ],
#        [1.801 ],
#        [1.902 ],
#        [2.003 ],
#        [2.104 ],
#        [2.205 ],
#        [2.307 ],
#        [1.062 ],
#        [1.167 ],
#        [1.273 ],
#        [1.379 ],
#        [1.485 ],
#        [1.591 ],
#        [1.698 ],
#        [1.804 ],
#        [1.911 ],
#        [2.018 ],
#        [2.125 ],
#        [2.232 ],
#        [2.339 ],
#        [2.446 ],
#        [1.126 ],
#        [1.237 ],
#        [1.349 ],
#        [1.461 ],
#        [1.573 ],
#        [1.685 ],
#        [1.798 ],
#        [1.91  ],
#        [2.023 ],
#        [2.135 ],
#        [2.248 ],
#        [2.361 ],
#        [2.475 ],
#        [2.588 ],
#        [1.191 ],
#        [1.309 ],
#        [1.427 ],
#        [1.545 ],
#        [1.663 ],
#        [1.781 ],
#        [1.899 ],
#        [2.018 ],
#        [2.137 ],
#        [2.255 ],
#        [2.374 ],
#        [2.493 ],
#        [2.613 ],
#        [2.732 ],
#        [1.258 ],
#        [1.382 ],
#        [1.506 ],
#        [1.63  ],
#        [1.754 ],
#        [1.878 ],
#        [2.003 ],
#        [2.127 ],
#        [2.252 ],
#        [2.377 ],
#        [2.502 ],
#        [2.628 ],
#        [2.753 ],
#        [2.879 ],
#        [1.326 ],
#        [1.456 ],
#        [1.586 ],
#        [1.716 ],
#        [1.847 ],
#        [1.977 ],
#        [2.108 ],
#        [2.239 ],
#        [2.37  ],
#        [2.501 ],
#        [2.632 ],
#        [2.764 ],
#        [2.896 ],
#        [3.028 ],
#        [1.395 ],
#        [1.531 ],
#        [1.668 ],
#        [1.804 ],
#        [1.941 ],
#        [2.078 ],
#        [2.215 ],
#        [2.352 ],
#        [2.489 ],
#        [2.627 ],
#        [2.765 ],
#        [2.902 ],
#        [3.041 ],
#        [3.179 ]])

# %%
print(X.shape)
print(y.shape)
# Out:
# (336, 2)
# (336, 1)

# %%
random_seed = int( random.random()* 100 )

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed, shuffle= None)

# %%
X_train.shape
# Out:
# (268, 2)

# %%
X_train_tr = torch.from_numpy(X_train).float()
X_test_tr = torch.from_numpy(X_test).float()
y_train_tr = torch.from_numpy(y_train).float()
y_test_tr = torch.from_numpy(y_test).float()

# %%
y_test_tr.dtype
# Out:
# torch.float32

# %%
# Parameters

# %%
batch_size = 16
learning_rate = 0.001
num_epochs = 200

# %%
# Normalization

# %%
x_means = X_train_tr.mean(0, keepdim= True)
x_stds = X_train_tr.std(0, keepdim= True)

# %%
# Create a Dataloader

# %%
train_ds = TensorDataset(X_train_tr, y_train_tr)
test_ds = TensorDataset(X_test_tr, y_test_tr)

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle=True)
test_dl = DataLoader(test_ds, batch_size, shuffle=True)

# %%
# Neural Network Architechture

# %%
#Linear Regression

class LinRegNet(nn.Module):
    def __init__(self, x_means, x_stds):
      super().__init__()

      self.x_means = x_means
      self.x_stds = x_stds

      self.fc1 = nn.Linear(2, 1)

    ## perform inference
    def forward(self, x):

      x = (x - self.x_means) / self.x_stds
      y_pred = self.fc1(x)
      return y_pred

# %%
# MLP: Multi layer Perceptron

class MLP_net(nn.Module):
    def __init__(self, x_means, x_stds):
      super().__init__()

      self.x_means = x_means
      self.x_stds = x_stds

      self.fc1 = nn.Linear(2, 12)
      self.act1 = nn.ReLU()
      self.fc2 = nn.Linear(12, 1)

    ## perform inference
    def forward(self, x):

      x = (x - self.x_means) / self.x_stds
      x = self.fc1(x)
      x = self.act1(x)
      y_pred = self.fc2(x)
      return y_pred

# %%
# Deep Learning with 2 hidden layers

class DL_net(nn.Module):
    def __init__(self, x_means, x_stds):
      super().__init__()

      self.x_means = x_means
      self.x_stds = x_stds

      self.fc1 = nn.Linear(2, 12)
      self.act1 = nn.ReLU()
      self.fc2 = nn.Linear(12, 8)
      self.act2 = nn.ReLU()
      self.fc3 = nn.Linear(8, 1)

    ## perform inference
    def forward(self, x):

      x = (x - self.x_means) / self.x_stds
      x = self.fc1(x)
      x = self.act1(x)
      x = self.fc2(x)
      x = self.act2(x)
      y_pred = self.fc3(x)
      return y_pred

# %%
# Traning Loop

# %%
def train_loop(num_epochs, model, loss_fn, opt):
       for epoch in range(num_epochs):

         for xb, yb in train_dl:
          y_pred = model(xb)
          loss = loss_fn(y_pred, yb)

          opt.zero_grad()
          loss.backward()
          opt.step()

         if epoch % 10 == 0:
            print(epoch, "loss=", loss)

# %%
# Main Loop

# %%
#model = LinRegNet(x_means, x_stds)
#model = MLP_net(x_means, x_stds)
model = DL_net(x_means, x_stds)
loss_fn = nn.MSELoss()
opt = optim.Adam(model.parameters(), lr=learning_rate)
train_loop(num_epochs, model, loss_fn, opt)
# Out:
# 0 loss= tensor(1.3474, grad_fn=<MseLossBackward0>)
# 10 loss= tensor(0.0383, grad_fn=<MseLossBackward0>)
# 20 loss= tensor(0.0229, grad_fn=<MseLossBackward0>)
# 30 loss= tensor(0.0051, grad_fn=<MseLossBackward0>)
# 40 loss= tensor(0.0030, grad_fn=<MseLossBackward0>)
# 50 loss= tensor(0.0019, grad_fn=<MseLossBackward0>)
# 60 loss= tensor(0.0013, grad_fn=<MseLossBackward0>)
# 70 loss= tensor(0.0010, grad_fn=<MseLossBackward0>)
# 80 loss= tensor(0.0040, grad_fn=<MseLossBackward0>)
# 90 loss= tensor(0.0017, grad_fn=<MseLossBackward0>)
# 100 loss= tensor(0.0040, grad_fn=<MseLossBackward0>)
# 110 loss= tensor(0.0068, grad_fn=<MseLossBackward0>)
# 120 loss= tensor(0.0031, grad_fn=<MseLossBackward0>)
# 130 loss= tensor(0.0012, grad_fn=<MseLossBackward0>)
# 140 loss= tensor(0.0012, grad_fn=<MseLossBackward0>)
# 150 loss= tensor(0.0064, grad_fn=<MseLossBackward0>)
# 160 loss= tensor(0.0072, grad_fn=<MseLossBackward0>)
# 170 loss= tensor(0.0059, grad_fn=<MseLossBackward0>)
# 180 loss= tensor(0.0011, grad_fn=<MseLossBackward0>)
# 190 loss= tensor(0.0047, grad_fn=<MseLossBackward0>)

# %%
# Evaluate Model

# %%
y_pred_test = model(X_test_tr)

# %%
y_pred_test.shape
# Out:
# torch.Size([68, 1])

# %%
print("Testing R**2:", r2_score(y_test_tr.detach().numpy(), y_pred_test.detach().numpy()))
# Out:
# Testing R**2: 0.9945050736359611

# %%
list_preds = []
list_reals = []

for i in range(len(X_test_tr)):
  print("*******************")
  print("pred, real")
  np_real = y_test_tr[i].detach().numpy()
  np_pred = y_pred_test[i].detach().numpy()
  print(np_pred[0], np_real[0])
  list_preds.append(np_pred[0])
  list_reals.append(np_real[0])
# Out:
# *******************
# pred, real
# 2.7617297 2.765
# *******************
# pred, real
# 0.62233335 0.593
# *******************
# pred, real
# 1.482243 1.408
# *******************
# pred, real
# 1.412621 1.232
# *******************
# pred, real
# 0.74514353 0.775
# *******************
# pred, real
# 3.0072086 3.041
# *******************
# pred, real
# 1.4684767 1.408
# *******************
# pred, real
# 1.1861103 0.913
# *******************
# pred, real
# 0.6089022 0.589
# *******************
# pred, real
# 1.4172848 1.45
# *******************
# pred, real
# 1.3724461 1.352
# *******************
# pred, real
# 1.1324823 1.059
# *******************
# pred, real
# 0.9994283 0.846
# *******************
# pred, real
# 2.308886 2.307
# *******************
# pred, real
# 0.75016344 0.774
# *******************
# pred, real
# 1.2187334 1.198
# *******************
# pred, real
# 0.63541704 0.67
# *******************
# pred, real
# 0.83482766 0.836
# *******************
# pred, real
# 1.9478041 1.944
# *******************
# pred, real
# 2.5162508 2.489
# *******************
# pred, real
# 0.31090406 0.355
# *******************
# pred, real
# 1.8882569 1.883
# *******************
# pred, real
# 0.74153674 0.715
# *******************
# pred, real
# 0.32962143 0.376
# *******************
# pred, real
# 0.30675036 0.34
# *******************
# pred, real
# 1.5379856 1.482
# *******************
# pred, real
# 0.91712797 0.846
# *******************
# pred, real
# 0.5924196 0.607
# *******************
# pred, real
# 1.3824645 1.314
# *******************
# pred, real
# 1.2865043 1.309
# *******************
# pred, real
# 0.6337327 0.629
# *******************
# pred, real
# 1.6597197 1.676
# *******************
# pred, real
# 0.6588355 0.666
# *******************
# pred, real
# 0.49322617 0.484
# *******************
# pred, real
# 2.6371882 2.632
# *******************
# pred, real
# 0.8373883 0.852
# *******************
# pred, real
# 0.18613893 0.195
# *******************
# pred, real
# 0.7252512 0.716
# *******************
# pred, real
# 0.35196215 0.379
# *******************
# pred, real
# 0.2765511 0.274
# *******************
# pred, real
# 1.5671299 1.573
# *******************
# pred, real
# 2.0857718 2.078
# *******************
# pred, real
# 2.3482203 2.339
# *******************
# pred, real
# 1.6649836 1.716
# *******************
# pred, real
# 1.2478474 1.273
# *******************
# pred, real
# 1.2798822 1.248
# *******************
# pred, real
# 0.53187996 0.539
# *******************
# pred, real
# 0.75336623 0.713
# *******************
# pred, real
# 2.8720078 2.879
# *******************
# pred, real
# 0.5861511 0.595
# *******************
# pred, real
# 2.384195 2.352
# *******************
# pred, real
# 0.54396254 0.52
# *******************
# pred, real
# 1.4650102 1.458
# *******************
# pred, real
# 1.8844872 1.899
# *******************
# pred, real
# 3.128741 3.179
# *******************
# pred, real
# 1.0399183 1.051
# *******************
# pred, real
# 2.213064 2.205
# *******************
# pred, real
# 2.116794 2.104
# *******************
# pred, real
# 0.5997013 0.593
# *******************
# pred, real
# 0.40329355 0.437
# *******************
# pred, real
# 0.85610247 0.898
# *******************
# pred, real
# 1.6954442 1.7
# *******************
# pred, real
# 0.124770135 0.118
# *******************
# pred, real
# 2.0198867 2.018
# *******************
# pred, real
# 1.0936708 0.933
# *******************
# pred, real
# 1.354275 1.395
# *******************
# pred, real
# 2.3881052 2.374
# *******************
# pred, real
# 1.4909002 1.536

# %%
plt.scatter(list_preds, list_reals)
plt.xlabel("Predictions")
plt.ylabel("Real Values")
plt.show()

# %%
plt.figure(figsize=(14, 5))
plt.plot(list_preds, label="Predictions")
plt.plot(list_reals, label="Real Values")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
